# %%
import pandas as pd
import numpy as np
import io
from matplotlib import pyplot as plt

# %%
df_error_average_response_time.reset_index(drop=True,inplace=True)
df_error_average_response_time
# Out:
#            mean  count
# 0    217.900000     10
# 1    309.111111     18
# 2    240.666667     15
# 3    285.909091     22
# 4    252.541667     24
# 5    288.500000     18
# 6    281.523810     21
# 7    255.947368     19
# 8    278.333333     15
# 9    284.461538     13
# 10   254.913043     23
# 11   283.250000     12
# 12   209.300000     20
# 13   294.722222     18
# 14   280.636364     11
# 15   220.235294     17
# 16   238.772727     22
# 17   277.565217     23
# 18   273.541667     24
# 19   244.631579     19
# 20   188.230769     13
# 21   263.944444     18
# 22   225.812500     16
# 23   289.850000     20
# 24   272.238095     21
# 25   308.733333     15
# 26   251.047619     21
# 27   315.300000     20
# 28   300.952381     21
# 29   236.333333     18
# ..          ...    ...
# 91   244.761905     21
# 92   303.750000     20
# 93   262.529412     17
# 94   237.440000     25
# 95   249.500000     28
# 96   240.789474     19
# 97   243.037037     27
# 98   237.400000     20
# ...
